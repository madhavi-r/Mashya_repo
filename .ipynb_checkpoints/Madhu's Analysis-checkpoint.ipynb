# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import os
import numpy as np
from scipy import stats


csv_file = "oasis_longitudinal.csv"
mri_data = pd.read_csv(csv_file)
mri_data.head()
# Out:
#   Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# 0  OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
# 1  OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# 2  OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
# 3  OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R   76    12
# 4  OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R   80    12
#
#    SES  MMSE  CDR  eTIV   nWBV    ASF
# 0  2.0  27.0  0.0  1987  0.696  0.883
# 1  2.0  30.0  0.0  2004  0.681  0.876
# 2  NaN  23.0  0.5  1678  0.736  1.046
# 3  NaN  28.0  0.5  1738  0.713  1.010
# 4  NaN  22.0  0.5  1698  0.701  1.034

# %%
mri_grouped_data = mri_data.set_index(['Subject ID','MRI ID'])
mri_grouped_data.head(10)
# Out:
#                                 Group  Visit  MR Delay M/F Hand  Age  EDUC  \
# Subject ID MRI ID
# OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R   87    14
#            OAS2_0001_MR2  Nondemented      2       457   M    R   88    14
# OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R   75    12
#            OAS2_0002_MR2     Demented      2       560   M    R   76    12
#            OAS2_0002_MR3     Demented      3      1895   M    R   80    12
# OAS2_0004  OAS2_0004_MR1  Nondemented      1         0   F    R   88    18
#            OAS2_0004_MR2  Nondemented      2       538   F    R   90    18
# OAS2_0005  OAS2_0005_MR1  Nondemented      1         0   M    R   80    12
#            OAS2_0005_MR2  Nondemented      2      1010   M    R   83    12
#            OAS2_0005_MR3  Nondemented      3      1603   M    R   85    12
#
#                           SES  MMSE  CDR  eTIV   nWBV    ASF
# Subject ID MRI ID
# ...

# %%
gender_based = mri_data.groupby(['M/F']).count()['Subject ID']
gender_based
# Out:
# M/F
# F    213
# M    160
# Name: Subject ID, dtype: int64

# %%
x_axis = gender_based.index
plt.grid()
plt.bar(x_axis, gender_based, alpha=0.5, align="center", color = ['b','g'])
# Out:
# <BarContainer object of 2 artists>

# %%
group_based = mri_data.groupby(['Group']).count()['Subject ID']
group_based
# Out:
# Group
# Converted       37
# Demented       146
# Nondemented    190
# Name: Subject ID, dtype: int64

# %%
x_axis = group_based.index
plt.grid()
plt.barh(x_axis, group_based, alpha=0.5, align="center", color = ['r','b','g'])
# Out:
# <BarContainer object of 3 artists>

# %%
bins = [60,66,71,76,81,86,91,100]
age_cat = ['60-65','66-70','71-75','76-80','81-85','86-90','91+']

# %%
mri_data['Age Category'] = pd.cut(mri_data['Age'],bins = bins, labels = age_cat, include_lowest = True)
mri_data.set_index(['Age Category']).head()
# Out:
#              Subject ID         MRI ID        Group  Visit  MR Delay M/F Hand  \
# Age Category
# 86-90         OAS2_0001  OAS2_0001_MR1  Nondemented      1         0   M    R
# 86-90         OAS2_0001  OAS2_0001_MR2  Nondemented      2       457   M    R
# 71-75         OAS2_0002  OAS2_0002_MR1     Demented      1         0   M    R
# 71-75         OAS2_0002  OAS2_0002_MR2     Demented      2       560   M    R
# 76-80         OAS2_0002  OAS2_0002_MR3     Demented      3      1895   M    R
#
#               Age  EDUC  SES  MMSE  CDR  eTIV   nWBV    ASF
# Age Category
# 86-90          87    14  2.0  27.0  0.0  1987  0.696  0.883
# 86-90          88    14  2.0  30.0  0.0  2004  0.681  0.876
# 71-75          75    12  NaN  23.0  0.5  1678  0.736  1.046
# 71-75          76    12  NaN  28.0  0.5  1738  0.713  1.010
# 76-80          80    12  NaN  22.0  0.5  1698  0.701  1.034

# %%
age_based = mri_data.groupby(['Age Category']).count()['Subject ID']
age_based.sum()
# Out:
# 373

# %%
x_axis = age_based.index
plt.grid()
plt.bar(x_axis, age_based, alpha=0.5, align="center", color = ['r','b','g','c','y','m','k'])
# Out:
# <BarContainer object of 7 artists>

# %%
mri_age_group = mri_data.groupby(['Age Category','Group']).count()['Subject ID'].unstack()
mri_age_group
# Out:
# Group         Converted  Demented  Nondemented
# Age Category
# 60-65                 1        11           20
# 66-70                 6        27           30
# 71-75                 5        42           40
# 76-80                 8        32           46
# 81-85                 9        24           28
# 86-90                 7         7           18
# 91+                   1         3            8

# %%
mri_age_group.plot(kind = 'bar', stacked = False, grid = True)

# %%
cdr_group = mri_data.groupby(['Age Category','CDR','M/F']).count()['Subject ID'].unstack()
cdr_group.dropna(how = 'any')
# Out:
# M/F                  F     M
# Age Category CDR
# 60-65        0.0  16.0   4.0
#              0.5   2.0   6.0
# 66-70        0.0  25.0  10.0
#              0.5   7.0  12.0
#              1.0   2.0   7.0
# 71-75        0.0  25.0  16.0
#              0.5  20.0  14.0
#              1.0   8.0   4.0
# 76-80        0.0  32.0  17.0
#              0.5   9.0  15.0
#              1.0   4.0   7.0
#              2.0   1.0   1.0
# 81-85        0.0  21.0  10.0
#              0.5   8.0  18.0
# 86-90        0.0  16.0   6.0
#              0.5   3.0   7.0
# 91+          0.0   7.0   1.0
#              0.5   1.0   1.0

# %%
# cdr_reg = mri_grouped_data.iloc[:,[0,1,9]]
x = mri_grouped.data[:,]

cdr_slope, cdr_int, cdr_r, cdr_p, cdr_std_err = stats.linregress(Visit, cdr_reg)
cdr_fit = cdr_slope * Visit + cdr_int
